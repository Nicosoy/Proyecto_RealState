# %% [markdown]
# # Real Estate Clean up
#
# This is a real dataset and it was downloaded using web scraping techniques. The data contains registers from fotocasa which is one of the most popular websites of real estate in Spain. Please, do not do this (web scraping) unless it is for academic purposes.
#
# The dataset was downloaded a few years ago by Henry Navarro and In no case were economic returns obtained from it.
#
# It contains thousands of data from real houses published on the web www.fotocasa.com. Your goal is to extract as much information as possible with the knowledge you have so far about data science, for example what is the most expensive house in the entire dataset?
#
# Let's start with precisely that question... Good luck!

# %% [markdown]
# #### Exercise 00. Read the dataset assets/real_estate.csv and try to visualize the table (★☆☆)

# %%
import pandas as pd

# this CSV file contains semicolons instead of comas as separator
ds = pd.read_csv('assets/real_estate.csv', sep=';')
ds
# Out:
#        Unnamed: 0  id_realEstates  isNew                    realEstate_name  \
# 0               1       153771986  False            ferrari 57 inmobiliaria
# 1               2       153867863  False  tecnocasa fuenlabrada ferrocarril
# 2               3       153430440  False                 look find boadilla
# 3               4       152776331  False  tecnocasa fuenlabrada ferrocarril
# 4               5       153180188  False            ferrari 57 inmobiliaria
# ...           ...             ...    ...                                ...
# 15330       15331       153901377  False                infocasa consulting
# 15331       15332       150394373  False                inmobiliaria pulpon
# 15332       15333       153901397  False             tecnocasa torrelodones
# 15333       15334       152607440  False                inmobiliaria pulpon
# 15334       15335       153901356  False                infocasa consulting
#
#        phone_realEstate                                       url_inmueble  \
# 0           912177526.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 1           916358736.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 2           916350408.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 3           916358736.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 4           912177526.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# ...                 ...                                                ...
# 15330       911360461.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 15331       912788039.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 15332       912780348.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 15333       912788039.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 15334       911360461.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
#
#        rooms  bathrooms  surface   price  ... level4Id level5Id level6Id  \
# 0        3.0        2.0    103.0  195000  ...        0        0        0
# 1        3.0        1.0      NaN   89000  ...        0        0        0
# 2        2.0        2.0     99.0  390000  ...        0        0        0
# 3        3.0        1.0     86.0   89000  ...        0        0        0
# 4        2.0        2.0    106.0  172000  ...        0        0        0
# ...      ...        ...      ...     ...  ...      ...      ...      ...
# 15330    2.0        1.0     96.0  259470  ...        0        0        0
# 15331    3.0        1.0    150.0  165000  ...        0        0        0
# 15332    4.0        2.0    175.0  495000  ...        0        0        0
# 15333    3.0        2.0    101.0  195000  ...        0        0        0
# 15334    3.0        2.0    152.0  765000  ...        0        0        0
#
#       level7Id level8Id accuracy          latitude          longitude zipCode  \
# 0            0        0        0  40,2948276786438  -3,44402412135624     NaN
# 1            0        0        1          40,28674           -3,79351     NaN
# 2            0        0        0  40,4115646786438  -3,90662252135624     NaN
# 3            0        0        0  40,2853785786438  -3,79508142135624     NaN
# 4            0        0        0  40,2998774864376  -3,45226301356237     NaN
# ...        ...      ...      ...               ...                ...     ...
# 15330        0        0        0          40,45416           -3,70286     NaN
# 15331        0        0        0          40,36652           -3,48951     NaN
# 15332        0        0        0          40,57444           -3,92124     NaN
# 15333        0        0        0          40,36967           -3,48105     NaN
# 15334        0        0        0          40,45773           -3,69068     NaN
#
#       customZone
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 15330        NaN
# 15331        NaN
# 15332        NaN
# 15333        NaN
# 15334        NaN
#
# [15335 rows x 37 columns]

# %% [markdown]
# #### Exercise 01. Which is the most expensive house in the dataset? (★☆☆)
#
# Print the address and the price of the selected house. For example:
#
# `The house with address General Street Nº5 is the most expensive and its price is 5000000 USD`

# %%
import pandas as pd

# this CSV file contains semicolons instead of comas as separator
ds = pd.read_csv('assets/real_estate.csv', sep=';')

a = ds.sort_values("price", ascending= False).head(1)
b = (a["price"])
c = (a["address"])
print("La casa con direccion", str(c),"es la mas cara y su precio es", str(b), "EUROS")
# Out:
# La casa con direccion 13110    El Escorial
# Name: address, dtype: object es la mas cara y su precio es 13110    8500000
# Name: price, dtype: int64 EUROS

# %% [markdown]
# #### Exercise 02. Which is cheapest house in the dataset? (★☆☆)
#
# Print the address and the price of the selected house. For example:
#
# `The house with address Concrete Street Nº1 is the cheapest and its price is 12000 USD`

# %%
import pandas as pd

# this CSV file contains semicolons instead of comas as separator
ds = pd.read_csv('assets/real_estate.csv', sep=';')

a = ds.sort_values("price", ascending= True).head(1)
b = (a["price"])
c = (a["address"])
print("La casa con direccion", str(c),"es la mas barata y su precio es", str(b), "EUROS")
# Out:
# La casa con direccion 1003    Paseo del Licenciado Vidriera, Getafe
# Name: address, dtype: object es la mas barata y su precio es 1003    0
# Name: price, dtype: int64 EUROS

# %% [markdown]
# #### Exercise 03. Which is the biggest and the smallest house in the dataset? (★☆☆)
#
# Print both the address and the surface of the selected houses. For example:
#
# `The bigger house is located on Yukka Street Nº10 and its surface is 5000 meters`
#
# `The smaller house is located on County Road 1 N and its surface is 200 meters`

# %%
import pandas as pd

#LA MAS GRANDE


ds = pd.read_csv('assets/real_estate.csv', sep=';')

a = ds.sort_values("surface", ascending= False).head(1)
b = (a["surface"])
c = (a["address"])
print("La casa mas grande esta en", str(c),"y sus superficie es de", str(b), "metros.")


#LA MAS CHICA

y = ds.sort_values("surface", ascending= True).head(1)
b = (y["surface"])
c = (y["address"])
print("La casa mas pequeña esta en", str(c),"y su superficie es de", str(b), "metros.")
# Out:
# La casa mas grande esta en 6794    Sevilla la Nueva
# Name: address, dtype: object y sus superficie es de 6794    249000.0
# Name: surface, dtype: float64 metros.
# La casa mas pequeña esta en 498    Calle Amparo,  Madrid Capital
# Name: address, dtype: object y su superficie es de 498    15.0
# Name: surface, dtype: float64 metros.

# %% [markdown]
# #### Exercise 04. How many populations (level5 column) the dataset contains? (★☆☆)
#
# Print the name of the populations with comma as separator. For example:
#
# `> print(populations)`
#
# `population1, population2, population3,...`

# %%
import pandas as pd


ds = pd.read_csv('assets/real_estate.csv', sep=';')

y = ds.sort_values("level5", ascending= True)
print(set(y["level5"]))
# Out:
# {'Parla', 'Garganta de los Montes', 'Algete', 'Montejo de la Sierra', 'El Álamo', 'Ambite', 'Fuenlabrada', 'Belmonte de Tajo', 'El Escorial', 'Arganda del Rey', 'Colmenarejo', ' Madrid Capital', 'Cabanillas de la Sierra', 'Orusco de Tajuña', 'Nuevo Baztán', 'Griñón', 'Carabaña', 'Moraleja de Enmedio', 'Moralzarzal', 'Torrejón de la Calzada', 'Valdelaguna', 'Zarzalejo', 'Tielmes', 'Pelayos de la Presa', 'Villar del Olmo', 'Campo Real', 'Manzanares El Real', 'Camarma de Esteruelas', 'Loeches', 'Fresno de Torote', 'Valdemaqueda', 'Cenicientos', 'Aranjuez', 'Coslada', 'Villanueva del Pardillo', 'El Molar (Madrid)', 'Valdetorres de Jarama', 'Serranillos del Valle', 'Villamanta', 'Valdaracete', 'Los Molinos', 'Miraflores de la Sierra', 'Colmenar de Oreja', 'Alcobendas', 'Mejorada del Campo', 'Villamantilla', 'Batres', 'Los Santos de la Humosa', 'Tres Cantos', 'San Lorenzo de El Escorial', 'La Cabrera', 'Talamanca de Jarama', 'El Vellón', 'Villaconejos', 'Villamanrique de Tajo', 'Valdilecha', 'Pinto', 'Villarejo de Salvanés', 'Cobeña', 'Valdeavero', 'Hoyo de Manzanares', 'Navas del Rey', 'Valdepiélagos', 'Casarrubuelos', 'Meco', 'Sevilla la Nueva', 'Cadalso de los Vidrios', 'Torrejón de Ardoz', 'Colmenar del Arroyo', 'Leganés', 'Valdemoro', 'San Agustín del Guadalix', 'Rivas-vaciamadrid', 'Braojos', 'Valverde de Alcalá', 'Cercedilla', 'Becerril de la Sierra', 'Ajalvir', 'Galapagar', 'Bustarviejo', 'Pozuelo de Alarcón', 'Gargantilla del Lozoya', 'Horcajo de la Sierra', 'Daganzo de Arriba', 'San Sebastián de los Reyes', 'Chinchón', 'Las Rozas de Madrid', 'Brea de Tajo', 'Alcalá de Henares', 'Piñuécar-gandullas', 'Pozuelo del Rey', 'Fresno de Torote - Serracines', 'Guadalix de la Sierra', 'Guadarrama', 'Arroyomolinos (Madrid)', 'Corpa', 'San Martín de la Vega', 'Gascones', 'Lozoya', 'Fuentidueña de Tajo', 'Navacerrada', 'Santorcaz', 'La Hiruela', 'Soto del Real', 'Móstoles', 'Boadilla del Monte', 'Villanueva de Perales', 'Anchuelo', 'Villaviciosa de Odón', 'Majadahonda', 'Brunete', 'Pezuela de las Torres', 'Pedrezuela', 'Collado Villalba', 'El Atazar', 'Fuente El Saz de Jarama', 'Perales de Tajuña', 'Patones', 'Titulcia', 'Buitrago del Lozoya', 'Getafe', 'Valdeolmos-Alalpardo', 'Torres de la Alameda', 'Robregordo', 'Villanueva de la Cañada', 'Robledo de Chavela', 'El Berrueco', 'Velilla de San Antonio', 'Torremocha de Jarama', 'Estremera', 'Villa del Prado', 'Ciempozuelos', 'Aldea del Fresno', 'El Boalo - Cerceda – Mataelpino', 'Chapinería', 'Colmenar Viejo', 'Rascafría', 'Santa María de la Alameda', 'Valdemanco', 'Alpedrete', 'Canencia', 'Valdemorillo', 'Redueña', 'Torrelaguna', 'Collado Mediano', 'Villavieja del Lozoya', 'Torrejón de Velasco', 'Morata de Tajuña', 'Quijorna', 'Villalbilla', 'Venturada', 'Humanes de Madrid', 'Ribatejada', 'Lozoyuela-navas-sieteiglesias', 'Puentes Viejas', 'Torrelodones', 'Fresnedillas de la Oliva', 'San Fernando de Henares', 'San Martín de Valdeiglesias', 'Navalagamella', 'Navalcarnero', 'Cubas de la Sagra', 'Alcorcón', 'Navarredonda', 'Madarcos', 'Pinilla del Valle', 'Navalafuente', 'Paracuellos de Jarama'}

# %% [markdown]
# #### Exercise 05. Does the dataset contain NAs? (★☆☆)
#
# Print a boolean value (`true` or `fase`) followed by the rows/cols that contains NAs.

# %%
import pandas as pd


ds = pd.read_csv('assets/real_estate.csv', sep=';')

x = ds.isnull()

print(x)
# Out:
#        Unnamed: 0  id_realEstates  isNew  realEstate_name  phone_realEstate  \
# 0           False           False  False            False             False
# 1           False           False  False            False             False
# 2           False           False  False            False             False
# 3           False           False  False            False             False
# 4           False           False  False            False             False
# ...           ...             ...    ...              ...               ...
# 15330       False           False  False            False             False
# 15331       False           False  False            False             False
# 15332       False           False  False            False             False
# 15333       False           False  False            False             False
# 15334       False           False  False            False             False
#
#        url_inmueble  rooms  bathrooms  surface  price  ...  level4Id  \
# 0             False  False      False    False  False  ...     False
# 1             False  False      False     True  False  ...     False
# 2             False  False      False    False  False  ...     False
# 3             False  False      False    False  False  ...     False
# 4             False  False      False    False  False  ...     False
# ...             ...    ...        ...      ...    ...  ...       ...
# 15330         False  False      False    False  False  ...     False
# 15331         False  False      False    False  False  ...     False
# 15332         False  False      False    False  False  ...     False
# 15333         False  False      False    False  False  ...     False
# 15334         False  False      False    False  False  ...     False
#
#        level5Id  level6Id  level7Id  level8Id  accuracy  latitude  longitude  \
# 0         False     False     False     False     False     False      False
# 1         False     False     False     False     False     False      False
# 2         False     False     False     False     False     False      False
# 3         False     False     False     False     False     False      False
# 4         False     False     False     False     False     False      False
# ...         ...       ...       ...       ...       ...       ...        ...
# 15330     False     False     False     False     False     False      False
# 15331     False     False     False     False     False     False      False
# 15332     False     False     False     False     False     False      False
# 15333     False     False     False     False     False     False      False
# 15334     False     False     False     False     False     False      False
#
#        zipCode  customZone
# 0         True        True
# 1         True        True
# 2         True        True
# 3         True        True
# 4         True        True
# ...        ...         ...
# 15330     True        True
# 15331     True        True
# 15332     True        True
# 15333     True        True
# 15334     True        True
#
# [15335 rows x 37 columns]

# %% [markdown]
# #### Exercise 06. Delete the NAs of the dataset, if applicable (★★☆)
#
# Print a comparison between the dimensions of the original DataFrame versus the DataFrame after the deletions

# %%
import pandas as pd


ds = pd.read_csv('assets/real_estate.csv', sep=';')

dff = ds.dropna()

print(dff)
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, id_realEstates, isNew, realEstate_name, phone_realEstate, url_inmueble, rooms, bathrooms, surface, price, date, description, address, country, level1, level2, level3, level4, level5, level6, level7, level8, upperLevel, countryId, level1Id, level2Id, level3Id, level4Id, level5Id, level6Id, level7Id, level8Id, accuracy, latitude, longitude, zipCode, customZone]
# Index: []
#
# [0 rows x 37 columns]

# %% [markdown]
# #### Exercise 07. Which is the mean of prices in the population (level5 column) of "Arroyomolinos (Madrid)"? (★★☆)
#
# Print the obtained value

# %%
import pandas as pd


ds = pd.read_csv('assets/real_estate.csv', sep=';')
madrid = ds.loc[ds["level5"] == "Arroyomolinos (Madrid)",["price"]].mean()
print(madrid)
# Out:
# price    294541.59854
# dtype: float64

# %% [markdown]
# #### Exercise 08. Plot the histogram of prices for the population (level5 column) of "Arroyomolinos (Madrid)" and explain what you observe (★★☆)
#
# Print the histogram of the prices and write in the Markdown cell a brief analysis about the plot.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt



ds = pd.read_csv('assets/real_estate.csv', sep=';')

arroyo_molinos = ds.loc[ds["level5"]=="Arroyomolinos (Madrid)"]
precio = arroyo_molinos["price"]
plt.hist(precio)
plt.show()

# %% [markdown]
# **TODO: Markdown**. To write here, double click to this cell and just remove this content and place the text you want to write. Then, execute the cell.

# %% [markdown]
# #### Exercise 09. Is the average of "Valdemorillo" and "Galapagar" prices the same? (★★☆)
#
# Print the both average prices and then write a conclusion about them

# %%
import pandas as pd


ds = pd.read_csv('assets/real_estate.csv', sep=';')
valdemorillo = ds.loc[ds["level5"] == "Valdemorillo",["price"]].mean()
galapagar = ds.loc[ds["level5"] == "Galapagar",["price"]].mean()
print(valdemorillo)
print(galapagar)

print("Los dos pueblos tienen precios similares.")
# Out:
# price    363860.293103
# dtype: float64
# price    360063.202381
# dtype: float64
# Los dos pueblos tienen precios similares.

# %% [markdown]
# #### Exercise 10. Is the average of "Valdemorillo" and "Galapagar" price per square meter (price/m2) the same? (★★☆)
#
# Print the both average prices and then write a conclusion about
#
# Hint: Create a new column called `pps` (price per square) and then analyse the values

# %%
import pandas as pd
ds = pd.read_csv('assets/real_estate.csv', sep=';')


new = ds[ds["level5"].isin(["Valdemorillo","Galapagar"])]

new["PPS"] = new["price"] / new["surface"]

print(new)
# Out:
#        Unnamed: 0  id_realEstates  isNew               realEstate_name  \
# 390           391       150350773  False           inmobiliaria gopard
# 545           546       153652973  False              remax punto cero
# 576           577       153002099  False                      sosdivar
# 617           618       150786470  False             grupo sigame 24hr
# 731           732       152777104  False              remax punto cero
# ...           ...             ...    ...                           ...
# 14850       14851       153173530  False        prorealty inmobiliaria
# 14887       14888       153913359  False  a casa coaching inmobiliario
# 14911       14912       153723972  False             urbenorte pozuelo
# 14913       14914       153722435  False             urbenorte pozuelo
# 15059       15060       153826016  False   mam gestiones inmobiliarias
#
#        phone_realEstate                                       url_inmueble  \
# 390                 NaN  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 545         912176425.0  https://www.fotocasa.es/es/comprar/vivienda/vi...
# 576         914890914.0  https://www.fotocasa.es/es/comprar/vivienda/pa...
# 617         911367437.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 731         912176425.0  https://www.fotocasa.es/es/comprar/vivienda/ge...
# ...                 ...                                                ...
# 14850       912664437.0  https://www.fotocasa.es/es/comprar/vivienda/la...
# 14887       911228327.0  https://www.fotocasa.es/es/comprar/vivienda/pa...
# 14911       911790847.0  https://www.fotocasa.es/es/comprar/vivienda/pa...
# 14913       911790847.0  https://www.fotocasa.es/es/comprar/vivienda/pa...
# 15059       911365778.0  https://www.fotocasa.es/es/comprar/vivienda/pi...
#
#        rooms  bathrooms  surface   price  ... level5Id level6Id level7Id  \
# 390      3.0        1.0     85.0  160000  ...        0        0        0
# 545      4.0        4.0    426.0  749000  ...        0        0        0
# 576      6.0        4.0    575.0  798500  ...        0        0        0
# 617      6.0        3.0    400.0  420000  ...        0        0        0
# 731      5.0        6.0    525.0  660000  ...        0        0        0
# ...      ...        ...      ...     ...  ...      ...      ...      ...
# 14850    4.0        4.0    291.0  415000  ...        0        0        0
# 14887    5.0        3.0    433.0  312000  ...        0        0        0
# 14911    4.0        4.0      NaN  530000  ...        0        0        0
# 14913    4.0        3.0    161.0  275000  ...        0        0        0
# 15059    1.0        1.0     55.0  103000  ...        0        0        0
#
#       level8Id accuracy    latitude   longitude zipCode customZone  \
# 390          0        0    40,50009    -4,07059     NaN        NaN
# 545          0        0     40,4899     -4,0227     NaN        NaN
# 576          0        1    40,54863    -3,98895     NaN        NaN
# 617          0        0    40,58297     -3,9646     NaN        NaN
# 731          0        0    40,56148    -3,97243     NaN        NaN
# ...        ...      ...         ...         ...     ...        ...
# 14850        0        0  40,5781972  -4,0231467     NaN        NaN
# 14887        0        0    40,50901    -4,04104     NaN        NaN
# 14911        0        0    40,53755    -4,08728     NaN        NaN
# 14913        0        0    40,50054    -4,05651     NaN        NaN
# 15059        0        1    40,49998    -4,06828     NaN        NaN
#
#                PPS
# 390    1882.352941
# 545    1758.215962
# 576    1388.695652
# 617    1050.000000
# 731    1257.142857
# ...            ...
# 14850  1426.116838
# 14887   720.554273
# 14911          NaN
# 14913  1708.074534
# 15059  1872.727273
#
# [142 rows x 38 columns]
# /tmp/ipykernel_696/3422633014.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new["PPS"] = new["price"] / new["surface"]

# %% [markdown]
# #### Exercise 11. Analyse the relation between the surface and the price of the houses (★★☆)
#
# Hint: You can make a `scatter plot` and then write a conclusion about it

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

ds = pd.read_csv('assets/real_estate.csv', sep=';')

price = ds["price"]
surface = ds["surface"]
plt.plot(price)
plt.show()

# %% [markdown]
# **TODO: Markdown**. To write here, double click to this cell and just remove this content and place the text you want to write. Then, execute the cell.

# %% [markdown]
# #### Exercise 12. How many real estate agencies the dataset contains? (★★☆)
#
# Print the obtained value

# %%
import pandas as pd

ds = pd.read_csv('assets/real_estate.csv', sep=';')

agencias = ds["realEstate_name"]
total =(set(agencias))

print("Tiene un total de",len(total), "agencias")
# Out:
# Tiene un total de 1822 agencias

# %% [markdown]
# #### Exercise 13. Which is the population (level5 column) that contains the most houses? (★★☆)
#
# Print both the population and the number of houses

# %%
import pandas as pd
from collections import Counter


ds = pd.read_csv('assets/real_estate.csv', sep=';')

population = ds["level5"]
a = list(population)
c = Counter(a)
print(c.most_common(1))
# Out:
# [(' Madrid Capital', 6643)]

# %% [markdown]
# #### Exercise 14. Now let's work with the "south belt" of madrid. Make a subset of the original DataFrame that contains the following populations (level5 column): "Fuenlabrada","Leganés","Getafe","Alcorcón" (★★☆)
#
# Hint: Filter the original DataFrame using the column `level5` and the function `isin`

# %%
import pandas as pd

ds = pd.read_csv('assets/real_estate.csv', sep=';')

madrid = ds[ds["level5"].isin(["Fuenlabrada","Leganés","Getafe","Alcorcón"])]


print(madrid)
# Out:
#        Unnamed: 0  id_realEstates  isNew  \
# 1               2       153867863  False
# 3               4       152776331  False
# 85             86       153152077  False
# 94             95       153995577  False
# 109           110       153586414  False
# ...           ...             ...    ...
# 15275       15276       153903887  False
# 15291       15292       151697757  False
# 15305       15306       153902389  False
# 15322       15323       153871864  False
# 15325       15326       153901467  False
#
#                                  realEstate_name  phone_realEstate  \
# 1              tecnocasa fuenlabrada ferrocarril       916358736.0
# 3              tecnocasa fuenlabrada ferrocarril       916358736.0
# 85                       sinergical inmobiliaria               NaN
# 94                               viviendas365com       911226014.0
# 109              area uno asesores inmobiliarios       912664081.0
# ...                                          ...               ...
# 15275  aliseda servicios de gestion inmobiliaria       911368198.0
# 15291                                    unipiso       912788631.0
# 15305                             jadein ferrero       914871639.0
# 15322                          gestion comercial       911220662.0
# 15325                              montehogar 68       911790675.0
#
#                                             url_inmueble  rooms  bathrooms  \
# 1      https://www.fotocasa.es/es/comprar/vivienda/ma...    3.0        1.0
# 3      https://www.fotocasa.es/es/comprar/vivienda/ma...    3.0        1.0
# 85     https://www.fotocasa.es/es/comprar/vivienda/le...    1.0        1.0
# 94     https://www.fotocasa.es/es/comprar/vivienda/le...    3.0        2.0
# 109    https://www.fotocasa.es/es/comprar/vivienda/ma...    3.0        3.0
# ...                                                  ...    ...        ...
# 15275  https://www.fotocasa.es/es/comprar/vivienda/al...    3.0        1.0
# 15291  https://www.fotocasa.es/es/comprar/vivienda/al...    3.0        2.0
# 15305  https://www.fotocasa.es/es/comprar/vivienda/ma...    3.0        2.0
# 15322  https://www.fotocasa.es/es/comprar/vivienda/ma...    3.0        1.0
# 15325  https://www.fotocasa.es/es/comprar/vivienda/ma...    2.0        2.0
#
#        surface   price  ... level4Id level5Id level6Id level7Id level8Id  \
# 1          NaN   89000  ...        0        0        0        0        0
# 3         86.0   89000  ...        0        0        0        0        0
# 85        50.0  107000  ...        0        0        0        0        0
# 94       120.0  320000  ...        0        0        0        0        0
# 109      142.0  425000  ...        0        0        0        0        0
# ...        ...     ...  ...      ...      ...      ...      ...      ...
# 15275     78.0  138000  ...        0        0        0        0        0
# 15291    110.0  279000  ...        0        0        0        0        0
# 15305     85.0  170000  ...        0        0        0        0        0
# 15322     91.0  112000  ...        0        0        0        0        0
# 15325     99.0  215000  ...        0        0        0        0        0
#
#       accuracy          latitude          longitude zipCode customZone
# 1            1          40,28674           -3,79351     NaN        NaN
# 3            0  40,2853785786438  -3,79508142135624     NaN        NaN
# 85           1          40,35059           -3,82693     NaN        NaN
# 94           0          40,31933           -3,77574     NaN        NaN
# 109          0        40,3313411         -3,8313868     NaN        NaN
# ...        ...               ...                ...     ...        ...
# 15275        1          40,31381           -3,83733     NaN        NaN
# 15291        0        40,3259051           -3,76318     NaN        NaN
# 15305        0        40,2882193         -3,8098617     NaN        NaN
# 15322        0          40,28282           -3,78892     NaN        NaN
# 15325        1          40,28062           -3,79869     NaN        NaN
#
# [907 rows x 37 columns]

# %% [markdown]
# #### Exercise 15. Make a bar plot of the median of the prices and explain what you observe (you must use the subset obtained in the question 14) (★★★)
#
# Print the bar of the median of the prices and write in the Markdown cell a brief analysis about the plot

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

ds = pd.read_csv('assets/real_estate.csv', sep=';')

madrid = ds[ds["level5"].isin(["Fuenlabrada","Leganés","Getafe","Alcorcón"])]

sl_1 = ds[ds["level5"].isin(["Fuenlabrada"])]
sl_2 = ds[ds["level5"].isin(["Leganés"])]
sl_3 = ds[ds["level5"].isin(["Getafe"])]
sl_4 = ds[ds["level5"].isin(["Alcorcón"])]

#PRECIOS MEDIANA

s_pre1 = sl_1["price"].median()
s_pre2 = sl_2["price"].median()
s_pre3 = sl_3["price"].median()
s_pre4 = sl_4["price"].median()

meridians = [155000.0, 169950.0, 285305.0, 179500.0]

ciudades = ["Fuenlabrada","Leganés","Getafe","Alcorcón"]

plt.plot(ciudades, meridians)
plt.show()

# %% [markdown]
# **TODO: Markdown**. To write here, double click to this cell and just remove this content and place the text you want to write. Then, execute the cell.

# %% [markdown]
# #### Exercise 16. Calculate the sample mean and variance of the variables: price, rooms, surface area and bathrooms (you must use the subset obtained in the question 14) (★★★)
#
# Print both values for each variable

# %%
import pandas as pd
import numpy as np

ds = pd.read_csv('assets/real_estate.csv', sep=';')
madrid = ds[ds["level5"].isin(["Fuenlabrada","Leganés","Getafe","Alcorcón"])]

sl_1 = ds[ds["level5"].isin(["Fuenlabrada"])]
sl_2 = ds[ds["level5"].isin(["Leganés"])]
sl_3 = ds[ds["level5"].isin(["Getafe"])]
sl_4 = ds[ds["level5"].isin(["Alcorcón"])]

#FUENLABRADA
prec1 = sl_1["price"].median()
surf1 = sl_1["surface"].median()
room1 = sl_1["rooms"].median()
bath1 = sl_1["bathrooms"].median()
prec2 = sl_1["price"].var()
surf2 = sl_1["surface"].var()
room2 = sl_1["rooms"].var()
bath2 = sl_1["bathrooms"].var()

#LEGANES
prec3 = sl_2["price"].median()
surf3 = sl_2["surface"].median()
room3 = sl_2["rooms"].median()
bath3 = sl_2["bathrooms"].median()
prec4 = sl_2["price"].var()
surf4 = sl_2["surface"].var()
room4 = sl_2["rooms"].var()
bath4 = sl_2["bathrooms"].var()

#GETAFE
prec5 = sl_3["price"].median()
surf5 = sl_3["surface"].median()
room5 = sl_3["rooms"].median()
bath5 = sl_3["bathrooms"].median()
prec6 = sl_3["price"].var()
surf6 = sl_3["surface"].var()
room6 = sl_3["rooms"].var()
bath6 = sl_3["bathrooms"].var()

#ALCORCON
prec7 = sl_4["price"].median()
surf7 = sl_4["surface"].median()
room7 = sl_4["rooms"].median()
bath7 = sl_4["bathrooms"].median()
prec8 = sl_4["price"].var()
surf8 = sl_4["surface"].var()
room8 = sl_4["rooms"].var()
bath8 = sl_4["bathrooms"].var()


print("Superficie, Precios, Habitaciones y Baños de FUENLABRADA (MEDIANA)")
print(surf1, prec1, room1, bath1)
print("Superficie, Precios, Habitaciones y Baños de FUENLABRADA (VARIABLE)")
print(surf2, prec2, room2, bath2)

print("-------------------------------------------------------------------")

print("Superficie, Precios, Habitaciones y Baños de LEGANES (MEDIANA)")
print(surf3, prec3, room3, bath3)
print("Superficie, Precios, Habitaciones y Baños de LEGANES (VARIABLE)")
print(surf4, prec4, room4, bath4)

print("-------------------------------------------------------------------")

print("Superficie, Precios, Habitaciones y Baños de GETAFE (MEDIANA)")
print(surf5, prec5, room5, bath5)
print("Superficie, Precios, Habitaciones y Baños de GETAFE (VARIABLE)")
print(surf6, prec6, room6, bath6)

print("-------------------------------------------------------------------")

print("Superficie, Precios, Habitaciones y Baños de ALCORCON (MEDIANA)")
print(surf7, prec7, room7, bath7)
print("Superficie, Precios, Habitaciones y Baños de ALCORCON (VARIABLE)")
print(surf8, prec8, room8, bath8)
# Out:
# Superficie, Precios, Habitaciones y Baños de FUENLABRADA (MEDIANA)
# 88.0 155000.0 3.0 1.0
# Superficie, Precios, Habitaciones y Baños de FUENLABRADA (VARIABLE)
# 2264.6438930902314 4701020700.469365 0.3558441558441558 0.3533670420592967
# -------------------------------------------------------------------
# Superficie, Precios, Habitaciones y Baños de LEGANES (MEDIANA)
# 80.0 169950.0 3.0 1.0
# Superficie, Precios, Habitaciones y Baños de LEGANES (VARIABLE)
# 3987.475194805194 11913940043.502485 0.8245898100172712 0.5530548359240068
# -------------------------------------------------------------------
# Superficie, Precios, Habitaciones y Baños de GETAFE (MEDIANA)
# 116.0 285305.0 3.0 2.0
# Superficie, Precios, Habitaciones y Baños de GETAFE (VARIABLE)
# 5828.110027662518 20982665802.243946 0.7727478821143063 0.6588091118800461
# -------------------------------------------------------------------
# Superficie, Precios, Habitaciones y Baños de ALCORCON (MEDIANA)
# 85.0 179500.0 3.0 1.0
# Superficie, Precios, Habitaciones y Baños de ALCORCON (VARIABLE)
# 4244.323833848635 15947825983.013088 0.9338946410285586 0.592734670154025

# %% [markdown]
# #### Exercise 17. What is the most expensive house of each population? You must use the subset obtained in the question 14 (★★☆)
#
# Print both the address and the price of the selected house of each population. You can print a DataFrame or a single line for each population

# %%
import pandas as pd
import numpy as np
ds = pd.read_csv('assets/real_estate.csv', sep=';')

sl_1 = ds[ds["level5"].isin(["Fuenlabrada"])]
sl_2 = ds[ds["level5"].isin(["Leganés"])]
sl_3 = ds[ds["level5"].isin(["Getafe"])]
sl_4 = ds[ds["level5"].isin(["Alcorcón"])]

#Index Maximo de Fuenlabrada
index1 = sl_1["price"].idxmax()

#Index Maximo de Leganés
index2 = sl_2["price"].idxmax()

#Index Maximo de Getafe
index3 = sl_3["price"].idxmax()

#Index Maximo de Alcorcón
index4 = sl_4["price"].idxmax()

address1  = ds.loc[index1, "address"]
price1 = ds.loc[index1, "price"]
print("En", address1,"," "su casa mas cara es de",price1,"€")

address2  = ds.loc[index2, "address"]
price2 = ds.loc[index2, "price"]
print("En", address2,"localizada en Leganés, su casa mas cara es de",price2,"€")


address3  = ds.loc[index3, "address"]
price3 = ds.loc[index3, "price"]
print("En", address3,"localizada en Getafe, su casa mas cara es de",price3,"€")


address4  = ds.loc[index4, "address"]
price4 = ds.loc[index4, "price"]
print("En", address4,"localizada en Alarcón, su casa mas cara es de",price4,"€")
# Out:
# En Calle de Paulo Freire, 5, Fuenlabrada ,su casa mas cara es de 490000 €
# En Avenida Reina Sofía, Leganés localizada en Leganés, su casa mas cara es de 650000 €
# En Getafe localizada en Getafe, su casa mas cara es de 1050000 €
# En Alcorcón localizada en Alarcón, su casa mas cara es de 950000 €

# %% [markdown]
# #### Exercise 18. Normalize the variable of prices for each population and plot the 4 histograms in the same plot (you must use the subset obtained in the question 14) (★★★)
#
# For the normalization method you can use the one you consider to, there is not a single correct answer to this question. Print the plot and write in the Markdown cell a brief analysis about the plot
#
# Hint: You can help yourself reviewing the multihist demo of Matplotlib

# %%
import pandas as pd
import numpy as np
ds = pd.read_csv('assets/real_estate.csv', sep=';')


madrid = ds[ds["level5"].isin(["Fuenlabrada","Leganés","Getafe","Alcorcón"])]

a = madrid.loc[madrid['level5'] == "Fuenlabrada"]
a_prices = a['price']
normalized_df=(a_prices-a_prices.min())/(a_prices.max()-a_prices.min())
print(normalized_df)


b = madrid.loc[madrid['level5'] == "Leganés"]
b_prices = b['price']
normalized_db=(b_prices-b_prices.min())/(b_prices.max()-b_prices.min())
print(normalized_db)


c = madrid.loc[madrid['level5'] == "Getafe"]
c_prices = c['price']
normalized_dc=(c_prices-c_prices.min())/(c_prices.max()-c_prices.min())
print(normalized_dc)


d = madrid.loc[madrid['level5'] == "Alcorcón"]
d_prices = d['price']
normalized_dd=(d_prices-d_prices.min())/(d_prices.max()-d_prices.min())
print(normalized_dd)
# Out:
# 1        0.000000
# 3        0.000000
# 161      0.375312
# 214      0.236908
# 219      0.186209
#            ...
# 15274    0.122195
# 15275    0.122195
# 15305    0.201995
# 15322    0.057357
# 15325    0.314214
# Name: price, Length: 233, dtype: float64
# 94       0.440678
# 189      0.000000
# 193      0.135593
# 272      0.335593
# 328      0.559329
#            ...
# 15015    0.091525
# 15024    0.338644
# 15238    0.050678
# 15263    0.559329
# 15291    0.371186
# Name: price, Length: 194, dtype: float64
# 169      0.276190
# 232      0.130857
# 233      0.129048
# 269      0.095143
# 381      0.433333
#            ...
# 14999    0.347619
# 15002    0.270944
# 15034    0.425714
# 15087    0.339200
# 15117    0.392857
# Name: price, Length: 290, dtype: float64
# 85       0.018055
# 109      0.388468
# 765      0.182295
# 816      0.241701
# 827      0.033081
#            ...
# 14896    0.050670
# 15144    0.277810
# 15166    0.097263
# 15191    0.263832
# 15223    0.192778
# Name: price, Length: 190, dtype: float64

# %% [markdown]
# **TODO: Markdown**. To write here, double click to this cell and just remove this content and place the text you want to write. Then, execute the cell.

# %% [markdown]
# #### Exercise 19. What can you say about the price per square meter (price/m2) between the towns of "Getafe" and "Alcorcón"? You must use the subset obtained in the question 14 (★★☆)
#
# Hint: Create a new column called `pps` (price per square) and then analyse the values

# %%
import pandas as pd
import numpy as np
ds = pd.read_csv('assets/real_estate.csv', sep=';')


madrid = ds[ds["level5"].isin(["Fuenlabrada","Leganés","Getafe","Alcorcón"])]

getafe = madrid[madrid["level5"].isin(["Getafe"])]
getafe["PPS"] = getafe["price"] / getafe["surface"]

print(getafe)


alcorcon = madrid[madrid["level5"].isin(["Alcorcón"])]
alcorcon["PPS"] = alcorcon["price"] / alcorcon["surface"]

print(alcorcon)
# Out:
#        Unnamed: 0  id_realEstates  isNew         realEstate_name  \
# 169           170       153920011  False            grupo tizona
# 232           233       152842726  False     aljada inmobiliaria
# 233           234       152842686  False     aljada inmobiliaria
# 269           270       153861480  False   whan house consulting
# 381           382       153880899  False            grupo tizona
# ...           ...             ...    ...                     ...
# 14999       15000       150500515  False                  identy
# 15002       15003       140064595  False  grupo gonzalez gervaso
# 15034       15035       153433007  False             aurea homes
# 15087       15088       150177594  False  grupo gonzalez gervaso
# 15117       15118       153433030  False             aurea homes
#
#        phone_realEstate                                       url_inmueble  \
# 169         911226046.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 232         916355578.0  https://www.fotocasa.es/es/comprar/vivienda/sa...
# 233         916355578.0  https://www.fotocasa.es/es/comprar/vivienda/sa...
# 269         925630418.0  https://www.fotocasa.es/es/comprar/vivienda/vi...
# 381         911226046.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# ...                 ...                                                ...
# 14999               NaN  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 15002       914871849.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 15034       911361016.0  https://www.fotocasa.es/vivienda/getafe/calle-...
# 15087       914871849.0  https://www.fotocasa.es/es/comprar/vivienda/ar...
# 15117       911361016.0  https://www.fotocasa.es/es/comprar/vivienda/ta...
#
#        rooms  bathrooms  surface   price  ... level5Id level6Id level7Id  \
# 169      6.0        2.0    195.0  290000  ...        0        0        0
# 232      3.0        1.0     65.0  137400  ...        0        0        0
# 233      3.0        1.0     83.0  135500  ...        0        0        0
# 269      3.0        1.0     62.0   99900  ...        0        0        0
# 381      4.0        2.0    280.0  455000  ...        0        0        0
# ...      ...        ...      ...     ...  ...      ...      ...      ...
# 14999    3.0        3.0    210.0  365000  ...        0        0        0
# 15002    3.0        2.0    122.0  284491  ...        0        0        0
# 15034    4.0        2.0    137.0  447000  ...        0        0        0
# 15087    3.0        2.0    115.0  356160  ...        0        0        0
# 15117    4.0        2.0    140.0  412500  ...        0        0        0
#
#       level8Id accuracy    latitude   longitude zipCode customZone  \
# 169          0        0    40,31111    -3,73066     NaN        NaN
# 232          0        0  40,3060558  -3,7346649     NaN        NaN
# 233          0        0  40,3035689  -3,7381336     NaN        NaN
# 269          0        0  40,3068987   -3,725108     NaN        NaN
# 381          0        0    40,28327    -3,74772     NaN        NaN
# ...        ...      ...         ...         ...     ...        ...
# 14999        0        0    40,30546    -3,75275     NaN        NaN
# 15002        0        1    40,30206    -3,73321     NaN        NaN
# 15034        0        1    40,31667    -3,74072     NaN        NaN
# 15087        0        0    40,30186    -3,73321     NaN        NaN
# 15117        0        1    40,31667    -3,74072     NaN        NaN
#
#                PPS
# 169    1487.179487
# 232    2113.846154
# 233    1632.530120
# 269    1611.290323
# 381    1625.000000
# ...            ...
# 14999  1738.095238
# 15002  2331.893443
# 15034  3262.773723
# 15087  3097.043478
# 15117  2946.428571
#
# [290 rows x 38 columns]
#        Unnamed: 0  id_realEstates  isNew                   realEstate_name  \
# 85             86       153152077  False           sinergical inmobiliaria
# 109           110       153586414  False   area uno asesores inmobiliarios
# 765           766       154002468   True                              raul
# 816           817       154001779   True                           deplace
# 827           828       154001766   True      tecnocasa ciudad de alcorcon
# ...           ...             ...    ...                               ...
# 14896       14897       150606951  False  soluciones inmobiliarias fergosa
# 15144       15145       151138764  False                oikos inmobiliaria
# 15166       15167       150646543  False               infocasa consulting
# 15191       15192       153078915  False                     daurum estate
# 15223       15224       153440884  False              redpiso alcorcon sur
#
#        phone_realEstate                                       url_inmueble  \
# 85                  NaN  https://www.fotocasa.es/es/comprar/vivienda/le...
# 109         912664081.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 765                 NaN  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 816         910750918.0  https://www.fotocasa.es/es/comprar/vivienda/la...
# 827         911795412.0  https://www.fotocasa.es/es/comprar/vivienda/la...
# ...                 ...                                                ...
# 14896       912176554.0  https://www.fotocasa.es/es/comprar/vivienda/pa...
# 15144       912664713.0  https://www.fotocasa.es/es/comprar/vivienda/to...
# 15166       911360461.0  https://www.fotocasa.es/es/comprar/vivienda/el...
# 15191       912179743.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 15223       910758927.0  https://www.fotocasa.es/es/comprar/vivienda/pa...
#
#        rooms  bathrooms  surface   price  ... level5Id level6Id level7Id  \
# 85       1.0        1.0     50.0  107000  ...        0        0        0
# 109      3.0        3.0    142.0  425000  ...        0        0        0
# 765      4.0        2.0    109.0  248000  ...        0        0        0
# 816      3.0        2.0     96.0  299000  ...        0        0        0
# 827      3.0        1.0     65.0  119900  ...        0        0        0
# ...      ...        ...      ...     ...  ...      ...      ...      ...
# 14896    2.0        1.0     65.0  135000  ...        0        0        0
# 15144    3.0        2.0     93.0  330000  ...        0        0        0
# 15166    3.0        1.0     73.0  175000  ...        0        0        0
# 15191    3.0        2.0    102.0  318000  ...        0        0        0
# 15223    2.0        2.0     85.0  257000  ...        0        0        0
#
#       level8Id accuracy          latitude          longitude zipCode  \
# 85           0        1          40,35059           -3,82693     NaN
# 109          0        0        40,3313411         -3,8313868     NaN
# 765          0        1           40,3526           -3,81587     NaN
# 816          0        0  40,3546326213562  -3,80197422135624     NaN
# 827          0        0          40,34949           -3,83127     NaN
# ...        ...      ...               ...                ...     ...
# 14896        0        0          40,34484           -3,83016     NaN
# 15144        0        0          40,35382           -3,80028     NaN
# 15166        0        0          40,35541           -3,82059     NaN
# 15191        0        0           40,3522           -3,80279     NaN
# 15223        0        0         40,344393          -3,839799     NaN
#
#       customZone          PPS
# 85           NaN  2140.000000
# 109          NaN  2992.957746
# 765          NaN  2275.229358
# 816          NaN  3114.583333
# 827          NaN  1844.615385
# ...          ...          ...
# 14896        NaN  2076.923077
# 15144        NaN  3548.387097
# 15166        NaN  2397.260274
# 15191        NaN  3117.647059
# 15223        NaN  3023.529412
#
# [190 rows x 38 columns]
# /tmp/ipykernel_633/4026714599.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   getafe["PPS"] = getafe["price"] / getafe["surface"]
# /tmp/ipykernel_633/4026714599.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   alcorcon["PPS"] = alcorcon["price"] / alcorcon["surface"]

# %% [markdown]
# #### Exercise 20. Make the same plot for 4 different populations (level5 column) and rearrange them on the same graph? You must use the subset obtained in the question 14 (★★☆)
# Hint: make a scatter plot of each population using subplots.

# %%
# TODO

# %% [markdown]
# #### Exercise 21. Make a plot of the coordinates (latitude and longitude columns) of the south belt of Madrid by color of each population (you must use the subset obtained in the question 14) (★★★★)
#
# Execute the following cell and then start coding in the next one. You must implement a simple code that transform the coordinates columns in a Python dictionary (add more information if needed) and then add it to the map

# %%
from ipyleaflet import Map, basemaps

# Map centred on (60 degrees latitude et -2.2 degrees longitude)
# Latitude, longitude
map = Map(center = (60, -2.2), zoom = 2, min_zoom = 1, max_zoom = 20, 
    basemap=basemaps.Stamen.Terrain)
map
# Out:
# Map(center=[60, -2.2], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_t…

# %%
## HERE: plot the coordinates of the estates

## PUT HERE YOUR CODE:
